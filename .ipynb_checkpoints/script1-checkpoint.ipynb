# %%
print('Hello world')

# %%
# %lsmagic

# %%
# %pwd

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

pi = np.pi
x = np.linspace(-5*pi, 5*pi, 1000)

plt.plot(x, np.sin(x)/x)
plt.show()
